# %%
# https://keras.io/
# !pip install -q keras
import keras

import keras
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import Adam
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from keras.layers.merge import concatenate

# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# Hyperparameters
batch_size = 128
num_classes = 10
epochs = 50
l = 10
num_filter = 20

# %%
# Load CIFAR10 Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_height, img_width, channel = x_train.shape[1],x_train.shape[2],x_train.shape[3]

# convert to one hot encoing 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 404s 2us/step

# %%
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
input = Input(shape=(img_height, img_width, channel,))

# Layer 1
layer1 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input)
layer1 = BatchNormalization(name='norm_1')(layer1)
layer1 = LeakyReLU(alpha=0.1)(layer1)
layer1 = MaxPooling2D(pool_size=(2, 2))(layer1)

# Layer 2
layer2 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(layer1)
layer2 = BatchNormalization(name='norm_2')(layer2)
layer2 = LeakyReLU(alpha=0.1)(layer2)
layer2 = MaxPooling2D(pool_size=(2, 2))(layer2)

# Layer 3
layer3 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(layer2)
layer3 = BatchNormalization(name='norm_3')(layer3)
layer3 = LeakyReLU(alpha=0.1)(layer3)

# Layer 4
layer4 = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(layer3)
layer4 = BatchNormalization(name='norm_4')(layer4)
layer4 = LeakyReLU(alpha=0.1)(layer4)

# Layer 5
layer5 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(layer4)
layer5 = BatchNormalization(name='norm_5')(layer5)
layer5 = LeakyReLU(alpha=0.1)(layer5)
layer5 = MaxPooling2D(pool_size=(2, 2))(layer5)

# Layer 6
layer6 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(layer5)
layer6 = BatchNormalization(name='norm_6')(layer6)
layer6 = LeakyReLU(alpha=0.1)(layer6)

# Layer 7
layer7 = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(layer6)
layer7 = BatchNormalization(name='norm_7')(layer7)
layer7 = LeakyReLU(alpha=0.1)(layer7)

# Layer 8
layer8 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(layer7)
layer8 = BatchNormalization(name='norm_8')(layer8)
layer8 = LeakyReLU(alpha=0.1)(layer8)
layer8 = MaxPooling2D(pool_size=(2, 2))(layer8)

# Layer 9
layer9 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(layer8)
layer9 = BatchNormalization(name='norm_9')(layer9)
layer9 = LeakyReLU(alpha=0.1)(layer9)

# Layer 10
layer10 = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(layer9)
layer10 = BatchNormalization(name='norm_10')(layer10)
layer10 = LeakyReLU(alpha=0.1)(layer10)

# Layer 11
layer11 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(layer10)
layer11 = BatchNormalization(name='norm_11')(layer11)
layer11 = LeakyReLU(alpha=0.1)(layer11)

# Layer 12
layer12 = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(layer11)
layer12 = BatchNormalization(name='norm_12')(layer12)
layer12 = LeakyReLU(alpha=0.1)(layer12)

skip_connection = layer12

# Layer 13
layer13 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(layer12)
layer13 = BatchNormalization(name='norm_13')(layer13)
layer13 = LeakyReLU(alpha=0.1)(layer13)


layer13 = MaxPooling2D(pool_size=(2, 2))(layer13)

# Layer 14
layer14 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(layer13)
layer14 = BatchNormalization(name='norm_14')(layer14)
layer14 = LeakyReLU(alpha=0.1)(layer14)

# Layer 15
layer15 = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(layer14)
layer15 = BatchNormalization(name='norm_15')(layer15)
layer15 = LeakyReLU(alpha=0.1)(layer15)

# Layer 16
layer16 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(layer15)
layer16 = BatchNormalization(name='norm_16')(layer16)
layer16 = LeakyReLU(alpha=0.1)(layer16)

# Layer 17
layer17 = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(layer16)
layer17 = BatchNormalization(name='norm_17')(layer17)
layer17 = LeakyReLU(alpha=0.1)(layer17)

# Layer 18
layer18 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(layer17)
layer18 = BatchNormalization(name='norm_18')(layer18)
layer18 = LeakyReLU(alpha=0.1)(layer18)

# Layer 19
layer19 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(layer18)
layer19 = BatchNormalization(name='norm_19')(layer19)
layer19 = LeakyReLU(alpha=0.1)(layer19)

# Layer 20
layer20 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(layer19)
layer20 = BatchNormalization(name='norm_20')(layer20)
layer20 = LeakyReLU(alpha=0.1)(layer20)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

layer21 = concatenate([skip_connection, layer20])

# Layer 22
layer22 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(layer21)
layer22 = BatchNormalization(name='norm_22')(layer22)
layer22 = LeakyReLU(alpha=0.1)(layer22)

# Layer 23
layer23 = Flatten()(layer22)

output = Dense(num_classes, activation='softmax')(layer23)

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 32, 32, 32)   864         input_4[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 32, 32, 32)   128         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 32, 32, 32)   0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 16, 16, 32)   0           leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 16, 16, 64)   18432       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 16, 16, 64)   256         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 16, 16, 64)   0           norm_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 64)     0           leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 8, 8, 128)    73728       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# norm_3 (BatchNormalization)     (None, 8, 8, 128)    512         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 8, 8, 128)    0           norm_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 8, 8, 64)     8192        leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 8, 8, 64)     256         conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 8, 8, 64)     0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 8, 8, 128)    73728       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 8, 8, 128)    512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 8, 8, 128)    0           norm_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 4, 4, 128)    0           leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 4, 4, 256)    294912      max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 4, 4, 256)    0           norm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 4, 4, 128)    32768       leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# norm_7 (BatchNormalization)     (None, 4, 4, 128)    512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 4, 4, 128)    0           norm_7[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 4, 4, 256)    294912      leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# norm_8 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 4, 4, 256)    0           norm_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 2, 2, 256)    0           leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 2, 2, 512)    1179648     max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# norm_9 (BatchNormalization)     (None, 2, 2, 512)    2048        conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 2, 2, 512)    0           norm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_65[0][0]
# __________________________________________________________________________________________________
# norm_10 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 2, 2, 256)    0           norm_10[0][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# norm_11 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 2, 2, 512)    0           norm_11[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# norm_12 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 2, 2, 256)    0           norm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# norm_13 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, 2, 2, 512)    0           norm_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 1, 1, 512)    0           leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 1, 1, 1024)   4718592     max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# norm_14 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_14[0][0]
# __________________________________________________________________________________________________
# conv_15 (Conv2D)                (None, 1, 1, 512)    524288      leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# norm_15 (BatchNormalization)    (None, 1, 1, 512)    2048        conv_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, 1, 1, 512)    0           norm_15[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 1, 1, 1024)   4718592     leaky_re_lu_71[0][0]
# __________________________________________________________________________________________________
# norm_16 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 1, 1, 512)    524288      leaky_re_lu_72[0][0]
# __________________________________________________________________________________________________
# norm_17 (BatchNormalization)    (None, 1, 1, 512)    2048        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, 1, 1, 512)    0           norm_17[0][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 1, 1, 1024)   4718592     leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# norm_18 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_74[0][0]
# __________________________________________________________________________________________________
# norm_19 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_19[0][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 2, 2, 64)     16384       leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_19[0][0]
# __________________________________________________________________________________________________
# norm_21 (BatchNormalization)    (None, 2, 2, 64)     256         conv_21[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_75[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)      (None, 2, 2, 64)     0           norm_21[0][0]
# __________________________________________________________________________________________________
# norm_20 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_20[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1, 1, 256)    0           leaky_re_lu_77[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_20[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1, 1, 1280)   0           lambda_3[0][0]
#                                                                  leaky_re_lu_76[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 1, 1, 1024)   11796480    concatenate_3[0][0]
# __________________________________________________________________________________________________
# norm_22 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_22[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1024)         0           leaky_re_lu_78[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           10250       flatten_3[0][0]
# ==================================================================================================
# Total params: 50,541,802
# Trainable params: 50,521,130
# Non-trainable params: 20,672
# __________________________________________________________________________________________________

# %%
# determine Loss function and Optimizer
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 109s 2ms/step - loss: 1.4439 - acc: 0.4784 - val_loss: 1.6102 - val_acc: 0.4870
# Epoch 2/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.9845 - acc: 0.6482 - val_loss: 1.3716 - val_acc: 0.5823
# Epoch 3/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.7833 - acc: 0.7258 - val_loss: 1.0152 - val_acc: 0.6622
# Epoch 4/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.6568 - acc: 0.7715 - val_loss: 1.0060 - val_acc: 0.6739
# Epoch 5/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.5617 - acc: 0.8055 - val_loss: 1.1207 - val_acc: 0.6650
# Epoch 6/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.4805 - acc: 0.8337 - val_loss: 1.0876 - val_acc: 0.6764
# Epoch 7/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.4147 - acc: 0.8576 - val_loss: 1.0143 - val_acc: 0.6914
# Epoch 8/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.3546 - acc: 0.8766 - val_loss: 0.9495 - val_acc: 0.7206
# Epoch 9/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.3029 - acc: 0.8956 - val_loss: 0.8670 - val_acc: 0.7407
# Epoch 10/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.2625 - acc: 0.9079 - val_loss: 0.8247 - val_acc: 0.7771
# Epoch 11/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.2212 - acc: 0.9236 - val_loss: 1.1808 - val_acc: 0.7039
# Epoch 12/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1910 - acc: 0.9337 - val_loss: 1.1602 - val_acc: 0.7139
# Epoch 13/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1636 - acc: 0.9429 - val_loss: 1.0083 - val_acc: 0.7490
# Epoch 14/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1395 - acc: 0.9510 - val_loss: 0.9426 - val_acc: 0.7745
# Epoch 15/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1298 - acc: 0.9536 - val_loss: 1.0367 - val_acc: 0.7510
# Epoch 16/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1170 - acc: 0.9590 - val_loss: 1.6033 - val_acc: 0.6797
# Epoch 17/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1031 - acc: 0.9637 - val_loss: 1.1011 - val_acc: 0.7603
# Epoch 18/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0978 - acc: 0.9661 - val_loss: 0.9798 - val_acc: 0.7756
# Epoch 19/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0906 - acc: 0.9682 - val_loss: 1.0396 - val_acc: 0.7651
# Epoch 20/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1018 - acc: 0.9649 - val_loss: 1.0516 - val_acc: 0.7656
# Epoch 21/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0761 - acc: 0.9735 - val_loss: 1.2350 - val_acc: 0.7395
# Epoch 22/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.0770 - acc: 0.9736 - val_loss: 1.0261 - val_acc: 0.7717
# Epoch 23/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0650 - acc: 0.9780 - val_loss: 1.0474 - val_acc: 0.7823
# Epoch 24/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0622 - acc: 0.9784 - val_loss: 1.0849 - val_acc: 0.7733
# Epoch 25/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0632 - acc: 0.9784 - val_loss: 1.0908 - val_acc: 0.7687
# Epoch 26/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0615 - acc: 0.9785 - val_loss: 1.2880 - val_acc: 0.7412
# Epoch 27/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0554 - acc: 0.9810 - val_loss: 1.1140 - val_acc: 0.7756
# Epoch 28/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0624 - acc: 0.9781 - val_loss: 1.1116 - val_acc: 0.7723
# Epoch 29/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0581 - acc: 0.9803 - val_loss: 1.0415 - val_acc: 0.7923
# Epoch 30/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0481 - acc: 0.9832 - val_loss: 1.2380 - val_acc: 0.7647
# Epoch 31/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0497 - acc: 0.9833 - val_loss: 1.2726 - val_acc: 0.7555
# Epoch 32/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0458 - acc: 0.9845 - val_loss: 1.1513 - val_acc: 0.7732
# Epoch 33/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0439 - acc: 0.9845 - val_loss: 1.2875 - val_acc: 0.7537
# Epoch 34/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0435 - acc: 0.9853 - val_loss: 1.2353 - val_acc: 0.7537
# Epoch 35/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0452 - acc: 0.9842 - val_loss: 1.0870 - val_acc: 0.7856
# Epoch 36/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0413 - acc: 0.9866 - val_loss: 1.3522 - val_acc: 0.7540
# Epoch 37/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1063 - acc: 0.9678 - val_loss: 1.2674 - val_acc: 0.7600
# Epoch 38/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.0286 - acc: 0.9907 - val_loss: 1.1979 - val_acc: 0.7747
# Epoch 39/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0319 - acc: 0.9897 - val_loss: 1.2514 - val_acc: 0.7877
# Epoch 40/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0346 - acc: 0.9886 - val_loss: 1.4051 - val_acc: 0.7417
# Epoch 41/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0346 - acc: 0.9883 - val_loss: 1.1007 - val_acc: 0.7938
# Epoch 42/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0337 - acc: 0.9889 - val_loss: 1.0763 - val_acc: 0.7920
# Epoch 43/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0328 - acc: 0.9888 - val_loss: 1.6002 - val_acc: 0.7301
# Epoch 44/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0362 - acc: 0.9878 - val_loss: 1.2313 - val_acc: 0.7690
# Epoch 45/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.0312 - acc: 0.9893 - val_loss: 1.1916 - val_acc: 0.7806
# Epoch 46/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.0340 - acc: 0.9879 - val_loss: 1.0586 - val_acc: 0.7974
# Epoch 47/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0308 - acc: 0.9894 - val_loss: 1.2361 - val_acc: 0.7745
# Epoch 48/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0289 - acc: 0.9902 - val_loss: 1.2966 - val_acc: 0.7649
# Epoch 49/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0323 - acc: 0.9893 - val_loss: 1.0839 - val_acc: 0.7930
# Epoch 50/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0308 - acc: 0.9899 - val_loss: 1.1237 - val_acc: 0.7843

# %%
# Test the model
score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Save the trained weights in to .h5 format
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
# Out:
# 10000/10000 [==============================] - 10s 1ms/step
# Test loss: 1.1237444856643677
# Test accuracy: 0.7843
# Saved the model to disk

# %%
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
from google.colab import files

files.download('Yolo_Basic_model.h5')
